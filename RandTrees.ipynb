# %%
import random

M = 500


L = [1,2]
L2 = [2,1]


for j in range(M):
    x = random.choice(L)
    for k in range(len(L)):
        if L[k] >= x:
            L[k] += 2
    for k in range(len(L)):
        if L2[k] >= x:
            L2[k] += 2
    L.append(x)
    L.append(x+1)
    L2.append(x+1)
    L2.append(x) 
    
    

    
zipped_lists = zip(L, L2)

sorted_pairs = sorted(zipped_lists)

tuples = zip(*sorted_pairs)

list1, list2 = [ list(tuple) for tuple in  tuples]
    
lines = []

for i in range(len(list1)):
    lines.append(str(list1[i])+" "+str(list2[i]))
    
f = open('RandTree6.txt', 'w')
for line in lines:
    f.write(line)
    f.write('\n')

# %%
f1 = open('RandTree6.txt', 'r')
print(f1.read())
# Out:
# 1 4
# 2 3
# 3 2
# 4 1
# 5 8
# 6 7
# 7 6
# 8 5
# 9 10
# 10 9
# 11 12
# 12 11
# 13 14
# 14 13
# 15 16
# 16 15
# 17 20
# 18 19
# 19 18
# 20 17
# 21 24
# 22 23
# 23 22
# 24 21
# 25 32
# 26 31
# 27 28
# 28 27
# 29 30
# 30 29
# 31 26
# 32 25
# 33 34
# 34 33
# 35 36
# 36 35
# 37 38
# 38 37
# 39 56
# 40 41
# 41 40
# 42 49
# 43 44
# 44 43
# 45 48
# 46 47
# 47 46
# 48 45
# 49 42
# 50 55
# 51 54
# 52 53
# 53 52
# 54 51
# 55 50
# 56 39
# 57 62
# 58 59
# 59 58
# 60 61
# 61 60
# 62 57
# 63 64
# 64 63
# 65 68
# 66 67
# 67 66
# 68 65
# 69 72
# 70 71
# 71 70
# 72 69
# 73 78
# 74 77
# 75 76
# 76 75
# 77 74
# 78 73
# 79 80
# 80 79
# 81 82
# 82 81
# 83 128
# 84 85
# 85 84
# 86 87
# 87 86
# 88 89
# 89 88
# 90 93
# 91 92
# 92 91
# 93 90
# 94 95
# 95 94
# 96 101
# 97 98
# 98 97
# 99 100
# 100 99
# 101 96
# 102 105
# 103 104
# 104 103
# 105 102
# 106 127
# 107 108
# 108 107
# 109 110
# 110 109
# 111 120
# 112 117
# 113 116
# 114 115
# 115 114
# 116 113
# 117 112
# 118 119
# 119 118
# 120 111
# 121 124
# 122 123
# 123 122
# 124 121
# 125 126
# 126 125
# 127 106
# 128 83
# 129 136
# 130 131
# 131 130
# 132 133
# 133 132
# 134 135
# 135 134
# 136 129
# 137 142
# 138 139
# 139 138
# 140 141
# 141 140
# 142 137
# 143 152
# 144 145
# 145 144
# 146 147
# 147 146
# 148 151
# 149 150
# 150 149
# 151 148
# 152 143
# 153 170
# 154 167
# 155 156
# 156 155
# 157 158
# 158 157
# 159 162
# 160 161
# 161 160
# 162 159
# 163 164
# 164 163
# 165 166
# 166 165
# 167 154
# 168 169
# 169 168
# 170 153
# 171 192
# 172 175
# 173 174
# 174 173
# 175 172
# 176 177
# 177 176
# 178 183
# 179 182
# 180 181
# 181 180
# 182 179
# 183 178
# 184 189
# 185 186
# 186 185
# 187 188
# 188 187
# 189 184
# 190 191
# 191 190
# 192 171
# 193 194
# 194 193
# 959 954
# 960 961
# 961 960
# 962 965
# 963 964
# 964 963
# 965 962
# 966 971
# 967 968
# 968 967
# 969 970
# 970 969
# 971 966
# 972 975
# 973 974
# 974 973
# 975 972
# 976 983
# 977 978
# 978 977
# 979 982
# 980 981
# 981 980
# 982 979
# 983 976
# 984 1001
# 985 986
# 986 985
# 987 988
# 988 987
# 989 990
# 990 989
# 991 992
# 992 991
# 993 994
# 994 993
# 995 996
# 996 995
# 997 1000
# 998 999
# 999 998
# 1000 997
# 1001 984
# 1002 375

# %%
import random

#random branching tree with vertex degree <= 2

M = 100
N = 20


L = [1,2, 3, 4]
L2 = [2,1, 4, 3]


for j in range(M):
    x = random.choice(L)
    if L2[L.index(x)] == x+1:
        for k in range(len(L)):
            if L[k] >= x+1:
                L[k] += 4
        for k in range(len(L)):
            if L2[k] >= x+1:
                L2[k] += 4
        L.append(x+1)
        L.append(x+2)
        L2.append(x+2)
        L2.append(x+1) 
        L.append(x+3)
        L.append(x+4)
        L2.append(x+4)
        L2.append(x+3) 
        
    
for j in range(N):
    x = random.choice(L)
    for k in range(len(L)):
        if L[k] >= x:
            L[k] += 2
    for k in range(len(L)):
        if L2[k] >= x:
            L2[k] += 2
    L.append(x)
    L.append(x+1)
    L2.append(x+1)
    L2.append(x)     

    
zipped_lists = zip(L, L2)

sorted_pairs = sorted(zipped_lists)

tuples = zip(*sorted_pairs)

list1, list2 = [ list(tuple) for tuple in  tuples]
    
lines = []

for i in range(len(list1)):
    lines.append(str(list1[i])+" "+str(list2[i]))
    
f = open('RandTree7.txt', 'w')
for line in lines:
    f.write(line)
    f.write('\n')

# %%
f = open('RandTree7.txt', 'r')
print(f.read())
# Out:
# 1 46
# 2 9
# 3 4
# 4 3
# 5 6
# 6 5
# 7 8
# 8 7
# 9 2
# 10 45
# 11 32
# 12 13
# 13 12
# 14 29
# 15 26
# 16 23
# 17 18
# 18 17
# 19 20
# 20 19
# 21 22
# 22 21
# 23 16
# 24 25
# 25 24
# 26 15
# 27 28
# 28 27
# 29 14
# 30 31
# 31 30
# 32 11
# 33 44
# 34 35
# 35 34
# 36 43
# 37 38
# 38 37
# 39 40
# 40 39
# 41 42
# 42 41
# 43 36
# 44 33
# 45 10
# 46 1
# 47 148
# 48 145
# 49 124
# 50 75
# 51 72
# 52 61
# 53 54
# 54 53
# 55 58
# 56 57
# 57 56
# 58 55
# 59 60
# 60 59
# 61 52
# 62 69
# 63 68
# 64 67
# 65 66
# 66 65
# 67 64
# 68 63
# 69 62
# 70 71
# 71 70
# 72 51
# 73 74
# 74 73
# 75 50
# 76 123
# 77 108
# 78 79
# 79 78
# 80 81
# 81 80
# 82 105
# 83 96
# 84 93
# 85 90
# 86 87
# 87 86
# 88 89
# 89 88
# 90 85
# 91 92
# 92 91
# 93 84
# 94 95
# 95 94
# 96 83
# 97 102
# 98 101
# 99 100
# 100 99
# 101 98
# 102 97
# 103 104
# 104 103
# 105 82
# 106 107
# 107 106
# 108 77
# 109 120
# 110 111
# 111 110
# 112 113
# 113 112
# 114 119
# 115 116
# 116 115
# 117 118
# 118 117
# 119 114
# 120 109
# 121 122
# 122 121
# 123 76
# 124 49
# 125 140
# 126 127
# 127 126
# 128 139
# 129 134
# 130 131
# 131 130
# 132 133
# 133 132
# 134 129
# 135 138
# 136 137
# 137 136
# 138 135
# 139 128
# 140 125
# 141 142
# 142 141
# 143 144
# 144 143
# 145 48
# 146 147
# 147 146
# 148 47

# %%
import random

#random branching tree with vertex degree <= 2

M = 200
N = 50


L = [1,2, 3, 4]
L2 = [2,1, 4, 3]


for j in range(M):
    x = random.choice(L)
    if L2[L.index(x)] == x+1:
        for k in range(len(L)):
            if L[k] >= x+1:
                L[k] += 4
        for k in range(len(L)):
            if L2[k] >= x+1:
                L2[k] += 4
        L.append(x+1)
        L.append(x+2)
        L2.append(x+2)
        L2.append(x+1) 
        L.append(x+3)
        L.append(x+4)
        L2.append(x+4)
        L2.append(x+3) 
        
    
zipped_lists = zip(L, L2)

sorted_pairs = sorted(zipped_lists)

tuples = zip(*sorted_pairs)

list1, list2 = [ list(tuple) for tuple in  tuples]
    
lines = []

for i in range(len(list1)):
    lines.append(str(list1[i])+" "+str(list2[i]))
    
f = open('RandTree7.txt', 'w')
for line in lines:
    f.write(line)
    f.write('\n')

# %%
L = [1,2,3,4]
L2 = [2,1,4,3]
curr_index = 0
for i in range(len(L)):
    if L2[i] == L[i]+1:
        curr_index = i
        for k in range(len(L)):
            if L[k] >= x+1:
                L[k] += 4
        for k in range(len(L)):
            if L2[k] >= x+1:
                L2[k] += 4
        L.append(x+1)
        L.append(x+2)
        L2.append(x+2)
        L2.append(x+1) 
        L.append(x+3)
        L.append(x+4)
        L2.append(x+4)
        L2.append(x+3)

# %%
#Binary Tree Generation
def roots(L,L2):
    v = []
    for e in L:
        if L2[L.index(e)] == e + 1:
            v.append(e)
    return v

L = [1,2,3,4]
L2 = [2,1,4,3]

M = 4

for i in range(M):
    
    Rt = roots(L,L2)
    Rt.sort()
    while Rt != []:
        x = Rt[0]
        Rt.remove(x)
        for j in range(len(Rt)):
            Rt[j] += 4
        for k in range(len(L)):
            if L[k] >= x+1:
                L[k] += 4
        for k in range(len(L)):
            if L2[k] >= x+1:
                L2[k] += 4
        L.append(x+1)
        L.append(x+2)
        L2.append(x+2)
        L2.append(x+1) 
        L.append(x+3)
        L.append(x+4)
        L2.append(x+4)
        L2.append(x+3) 
        
        
zipped_lists = zip(L, L2)

sorted_pairs = sorted(zipped_lists)

tuples = zip(*sorted_pairs)

list1, list2 = [ list(tuple) for tuple in  tuples]
    
lines = []

for i in range(len(list1)):
    lines.append(str(list1[i])+" "+str(list2[i]))
    
f = open('RandTree8.txt', 'w')
for line in lines:
    f.write(line)
    f.write('\n')

# %%
f = open('RandTree7.txt', 'r')
print(f.read())
# Out:
# 1 86
# 2 63
# 3 28
# 4 13
# 5 6
# 6 5
# 7 12
# 8 9
# 9 8
# 10 11
# 11 10
# 12 7
# 13 4
# 14 27
# 15 24
# 16 21
# 17 18
# 18 17
# 19 20
# 20 19
# 21 16
# 22 23
# 23 22
# 24 15
# 25 26
# 26 25
# 27 14
# 28 3
# 29 62
# 30 39
# 31 36
# 32 33
# 33 32
# 34 35
# 35 34
# 36 31
# 37 38
# 38 37
# 39 30
# 40 61
# 41 50
# 42 43
# 43 42
# 44 49
# 45 46
# 46 45
# 47 48
# 48 47
# 49 44
# 50 41
# 51 60
# 52 53
# 53 52
# 54 59
# 55 56
# 56 55
# 57 58
# 58 57
# 59 54
# 60 51
# 61 40
# 62 29
# 63 2
# 64 85
# 65 78
# 66 71
# 67 68
# 68 67
# 69 70
# 70 69
# 71 66
# 72 77
# 73 74
# 74 73
# 75 76
# 76 75
# 77 72
# 78 65
# 79 84
# 80 81
# 81 80
# 82 83
# 83 82
# 84 79
# 85 64
# 86 1
# 87 200
# 88 105
# 89 98
# 90 95
# 91 92
# 92 91
# 93 94
# 94 93
# 95 90
# 96 97
# 97 96
# 98 89
# 99 104
# 100 101
# 101 100
# 102 103
# 103 102
# 104 99
# 105 88
# 106 199
# 107 196
# 108 125
# 109 118
# 110 111
# 111 110
# 112 117
# 113 114
# 114 113
# 115 116
# 116 115
# 117 112
# 118 109
# 119 124
# 120 121
# 121 120
# 122 123
# 123 122
# 124 119
# 125 108
# 126 195
# 127 192
# 128 165
# 129 154
# 130 151
# 131 132
# 132 131
# 133 150
# 134 147
# 135 144
# 136 141
# 137 138
# 138 137
# 139 140
# 140 139
# 141 136
# 142 143
# 143 142
# 144 135
# 145 146
# 146 145
# 147 134
# 148 149
# 149 148
# 150 133
# 151 130
# 152 153
# 153 152
# 154 129
# 155 164
# 156 157
# 157 156
# 158 163
# 159 160
# 160 159
# 161 162
# 162 161
# 163 158
# 164 155
# 165 128
# 166 191
# 167 180
# 168 169
# 169 168
# 170 179
# 171 172
# 172 171
# 173 178
# 174 175
# 175 174
# 176 177
# 177 176
# 178 173
# 179 170
# 180 167
# 181 190
# 182 183
# 183 182
# 184 189
# 185 186
# 186 185
# 187 188
# 188 187
# 189 184
# 190 181
# 191 166
# 192 127
# 193 194
# 194 193
# 195 126
# 196 107
# 197 198
# 198 197
# 199 106
# 200 87

# %%
#Degree Three Vertex Tree Generation
def roots(L,L2):
    v = []
    for e in L:
        if L2[L.index(e)] == e + 1:
            v.append(e)
    return v

L = [1,2,3,4,5,6]
L2 = [2,1,4,3,6,5]

M = 3

for i in range(M):
    
    Rt = roots(L,L2)
    Rt.sort()
    while Rt != []:
        x = Rt[0]
        Rt.remove(x)
        for j in range(len(Rt)):
            Rt[j] += 4
        for k in range(len(L)):
            if L[k] >= x+1:
                L[k] += 4
        for k in range(len(L)):
            if L2[k] >= x+1:
                L2[k] += 4
        L.append(x+1)
        L.append(x+2)
        L2.append(x+2)
        L2.append(x+1) 
        L.append(x+3)
        L.append(x+4)
        L2.append(x+4)
        L2.append(x+3) 
        
        
zipped_lists = zip(L, L2)

sorted_pairs = sorted(zipped_lists)

tuples = zip(*sorted_pairs)

list1, list2 = [ list(tuple) for tuple in  tuples]
    
lines = []

for i in range(len(list1)):
    lines.append(str(list1[i])+" "+str(list2[i]))
    
f = open('RandTree9.txt', 'w')
for line in lines:
    f.write(line)
    f.write('\n')

# %%
f = open('RandTree9.txt', 'r')
print(f.read())
# Out:
# 1 30
# 2 15
# 3 8
# 4 5
# 5 4
# 6 7
# 7 6
# 8 3
# 9 14
# 10 11
# 11 10
# 12 13
# 13 12
# 14 9
# 15 2
# 16 29
# 17 22
# 18 19
# 19 18
# 20 21
# 21 20
# 22 17
# 23 28
# 24 25
# 25 24
# 26 27
# 27 26
# 28 23
# 29 16
# 30 1
# 31 60
# 32 45
# 33 38
# 34 35
# 35 34
# 36 37
# 37 36
# 38 33
# 39 44
# 40 41
# 41 40
# 42 43
# 43 42
# 44 39
# 45 32
# 46 59
# 47 52
# 48 49
# 49 48
# 50 51
# 51 50
# 52 47
# 53 58
# 54 55
# 55 54
# 56 57
# 57 56
# 58 53
# 59 46
# 60 31
# 61 90
# 62 75
# 63 68
# 64 65
# 65 64
# 66 67
# 67 66
# 68 63
# 69 74
# 70 71
# 71 70
# 72 73
# 73 72
# 74 69
# 75 62
# 76 89
# 77 82
# 78 79
# 79 78
# 80 81
# 81 80
# 82 77
# 83 88
# 84 85
# 85 84
# 86 87
# 87 86
# 88 83
# 89 76
# 90 61

# %%
# add line segment left/ right

#Degree Three Vertex Tree Generation
def line(l, r):
    
    L = [1,2,3,4,5,6]
    L2 = [2,1,4,3,6,5]
    
    l_vertex = 3
    r_vertex = 5
    
    for i in range(l):
        for element in L:
            α = L.index(element)
            if element > l_vertex:
                L[α] += 2
        for element in L2:
            α = L.index(element)
            if L2[α] > l_vertex:
                L2[α] += 2
        L.append(l_vertex+1)
        L.append(l_vertex+2)
        L2.append(l_vertex+2)
        L2.append(l_vertex+1)
        l_vertex += 1
        r_vertex += 2

    for i in range(r):
        for element in L:
            α = L.index(element)
            if element > r_vertex:
                L[α] += 2
        for element in L2:
            α = L2.index(element)
            if L2[α] > r_vertex:
                L2[α] += 2
        L.append(r_vertex+1)
        L.append(r_vertex+2)
        L2.append(r_vertex+2)
        L2.append(r_vertex+1)
        r_vertex += 1


    zipped_lists = zip(L, L2)

    sorted_pairs = sorted(zipped_lists)

    tuples = zip(*sorted_pairs)

    list1, list2 = [ list(tuple) for tuple in  tuples]

    lines = []

    for i in range(len(list1)):
        lines.append(str(list1[i])+" "+str(list2[i]))

    f = open('RandTree10.txt', 'w')
    for line in lines:
        f.write(line)
        f.write('\n')
line(1, 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-311-19f438d03250> in <module>
#      59         f.write(line)
#      60         f.write('\n')
# ---> 61 line(1, 0)
#
# <ipython-input-311-19f438d03250> in line(l, r)
#      16                 L[α] += 2
#      17         for element in L2:
# ---> 18             α = L.index(element)
#      19             if L2[α] > l_vertex:
#      20                 L2[α] += 2
#
# ValueError: 4 is not in list

# %%
f = open('RandTree10.txt', 'r')
print(f.read())
# Out:
# 1 2
# 2 1
# 3 6
# 4 5
# 5 4
# 6 5
# 7 8
# 8 3
